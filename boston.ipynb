# %%
import pandas as pd

boston = pd.read_csv('Boston.csv', index_col=0)
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 1   4.98  24.0
# 2   9.14  21.6
# 3   4.03  34.7
# 4   2.94  33.4
# 5   5.33  36.2

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
boston.shape
# Out:
# (506, 13)

# %%
features = boston.drop('medv', axis=1)
target = boston['medv']

# %%
pd.plotting.scatter_matrix(features, figsize=(10, 10))
print()

# %%
# Calculate thresholds for high values
high_crime_threshold = features['crim'].quantile(0.90)
high_tax_threshold = features['tax'].quantile(0.90)
high_ptratio_threshold = features['ptratio'].quantile(0.90)

# Identify suburbs with particularly high values
high_crime_suburbs = features[features['crim'] > high_crime_threshold]
high_tax_suburbs = features[features['tax'] > high_tax_threshold]
high_ptratio_suburbs = features[features['ptratio'] > high_ptratio_threshold]

# %%
high_crime_suburbs.describe()
# Out:
#             crim    zn  indus  chas        nox         rm         age  \
# count  51.000000  51.0   51.0  51.0  51.000000  51.000000   51.000000
# mean   22.652214   0.0   18.1   0.0   0.672333   5.750373   93.743137
# std    16.588706   0.0    0.0   0.0   0.046287   0.803842    9.779064
# min    10.834200   0.0   18.1   0.0   0.580000   3.863000   56.700000
# 25%    13.600150   0.0   18.1   0.0   0.659000   5.290500   91.550000
# 50%    15.860300   0.0   18.1   0.0   0.679000   5.854000   97.300000
# 75%    24.021000   0.0   18.1   0.0   0.700000   6.361500  100.000000
# max    88.976200   0.0   18.1   0.0   0.740000   7.313000  100.000000
#
#              dis   rad    tax  ptratio      lstat
# count  51.000000  51.0   51.0     51.0  51.000000
# mean    1.693161  24.0  666.0     20.2  22.921961
# std     0.351769   0.0    0.0      0.0   6.943948
# min     1.137000  24.0  666.0     20.2  10.110000
# 25%     1.452500  24.0  666.0     20.2  17.630000
# ...

# %%
features['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
features['ptratio'].median()
# Out:
# 19.05

# %%
features.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
features.loc[target[target == target.min()].index]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat
# 399     20.2  30.59
# 406     20.2  22.98

# %%
more_than_7_rooms = features[features['rm'] > 7]
more_than_7_rooms.describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  64.000000  64.000000  64.000000  64.000000  64.000000  64.000000
# mean    0.979109  28.171875   5.775625   0.125000   0.504455   7.570094
# std     2.807599  34.053089   5.544494   0.333333   0.092863   0.481467
# min     0.009060   0.000000   0.460000   0.000000   0.394000   7.007000
# 25%     0.045023   0.000000   2.460000   0.000000   0.430250   7.183250
# 50%     0.097860  20.000000   3.970000   0.000000   0.488000   7.414000
# 75%     0.542893  45.000000   6.200000   0.000000   0.582500   7.858500
# max    19.609100  95.000000  19.580000   1.000000   0.718000   8.780000
#
#               age        dis        rad         tax    ptratio      lstat
# count   64.000000  64.000000  64.000000   64.000000  64.000000  64.000000
# mean    60.640625   4.199617   5.984375  312.234375  16.259375   5.474062
# std     27.858587   2.074423   5.655429  118.311365   2.351407   2.906582
# ...

# %%
more_than_8_rooms = features[features['rm'] > 8]
more_than_8_rooms.describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...
